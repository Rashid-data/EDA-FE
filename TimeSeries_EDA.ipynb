# %% [markdown]
# Time Series EDA

# %%
# !pip install pandas-datareader

# %%
import pandas_datareader as pdr
import pandas as pd
from datetime import datetime

# %%
# !pip install yfinance

# %%
import yfinance as yf
data = yf.download('TSLA', start='2022-01-01', end='2023-01-01')
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
data.head()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2022-01-03  382.583344  400.356659  378.679993  399.926666  399.926666
# 2022-01-04  396.516663  402.666656  374.350006  383.196655  383.196655
# 2022-01-05  382.216675  390.113342  360.336670  362.706665  362.706665
# 2022-01-06  359.000000  362.666656  340.166656  354.899994  354.899994
# 2022-01-07  360.123322  360.309998  336.666656  342.320007  342.320007
#
#                Volume
# Date
# 2022-01-03  103931400
# 2022-01-04  100248300
# 2022-01-05   80119800
# 2022-01-06   90336600
# 2022-01-07   84164700

# %%
data.plot()
# Out:
# <Axes: xlabel='Date'>

# %%
data["High"].plot()
# Out:
# <Axes: xlabel='Date'>

# %%
#x limit & y limit
data["High"].plot(xlim=['2022-05-01','2022-08-01'])
# Out:
# <Axes: xlabel='Date'>

# %%
data["High"].plot(xlim=['2022-01-01','2023-01-01'],ylim=[200,300])
# Out:
# <Axes: xlabel='Date'>

# %%
data["High"].plot(xlim=['2022-01-01','2023-01-01'],ylim=[200,300],c="green",ls="--")
# Out:
# <Axes: xlabel='Date'>

# %%
index=data.loc['2022-01-01':'2022-04-01']

# %%
index.head()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2022-01-03  382.583344  400.356659  378.679993  399.926666  399.926666
# 2022-01-04  396.516663  402.666656  374.350006  383.196655  383.196655
# 2022-01-05  382.216675  390.113342  360.336670  362.706665  362.706665
# 2022-01-06  359.000000  362.666656  340.166656  354.899994  354.899994
# 2022-01-07  360.123322  360.309998  336.666656  342.320007  342.320007
#
#                Volume
# Date
# 2022-01-03  103931400
# 2022-01-04  100248300
# 2022-01-05   80119800
# 2022-01-06   90336600
# 2022-01-07   84164700

# %%
share_open=data.loc['2022-01-01':'2022-04-01']['Open']

# %%
share_open
# Out:
# Date
# 2022-01-03    382.583344
# 2022-01-04    396.516663
# 2022-01-05    382.216675
# 2022-01-06    359.000000
# 2022-01-07    360.123322
#                  ...
# 2022-03-28    355.033325
# 2022-03-29    369.329987
# 2022-03-30    363.723328
# 2022-03-31    364.856659
# 2022-04-01    360.383331
# Name: Open, Length: 63, dtype: float64

# %%
index=data.loc['2022-01-01':'2022-04-01'].index

# %%
index
# Out:
# DatetimeIndex(['2022-01-03', '2022-01-04', '2022-01-05', '2022-01-06',
#                '2022-01-07', '2022-01-10', '2022-01-11', '2022-01-12',
#                '2022-01-13', '2022-01-14', '2022-01-18', '2022-01-19',
#                '2022-01-20', '2022-01-21', '2022-01-24', '2022-01-25',
#                '2022-01-26', '2022-01-27', '2022-01-28', '2022-01-31',
#                '2022-02-01', '2022-02-02', '2022-02-03', '2022-02-04',
#                '2022-02-07', '2022-02-08', '2022-02-09', '2022-02-10',
#                '2022-02-11', '2022-02-14', '2022-02-15', '2022-02-16',
#                '2022-02-17', '2022-02-18', '2022-02-22', '2022-02-23',
#                '2022-02-24', '2022-02-25', '2022-02-28', '2022-03-01',
#                '2022-03-02', '2022-03-03', '2022-03-04', '2022-03-07',
#                '2022-03-08', '2022-03-09', '2022-03-10', '2022-03-11',
#                '2022-03-14', '2022-03-15', '2022-03-16', '2022-03-17',
# ...

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
figure,axis=plt.subplots()
plt.tight_layout()
figure.autofmt_xdate()
axis.plot(index, share_open)

# %%
 #Datetime Index

# %%
data.reset_index()
# Out:
#           Date        Open        High         Low       Close   Adj Close  \
# 0   2022-01-03  382.583344  400.356659  378.679993  399.926666  399.926666
# 1   2022-01-04  396.516663  402.666656  374.350006  383.196655  383.196655
# 2   2022-01-05  382.216675  390.113342  360.336670  362.706665  362.706665
# 3   2022-01-06  359.000000  362.666656  340.166656  354.899994  354.899994
# 4   2022-01-07  360.123322  360.309998  336.666656  342.320007  342.320007
# ..         ...         ...         ...         ...         ...         ...
# 246 2022-12-23  126.370003  128.619995  121.019997  123.150002  123.150002
# 247 2022-12-27  117.500000  119.669998  108.760002  109.099998  109.099998
# 248 2022-12-28  110.349998  116.269997  108.239998  112.709999  112.709999
# 249 2022-12-29  120.389999  123.570000  117.500000  121.820000  121.820000
# 250 2022-12-30  119.949997  124.480003  119.750000  123.180000  123.180000
#
#         Volume
# 0    103931400
# 1    100248300
# 2     80119800
# ...

# %%
data=data.reset_index()

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 251 entries, 0 to 250
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       251 non-null    datetime64[ns]
#  1   Open       251 non-null    float64
#  2   High       251 non-null    float64
#  3   Low        251 non-null    float64
#  4   Close      251 non-null    float64
#  5   Adj Close  251 non-null    float64
#  6   Volume     251 non-null    int64
# dtypes: datetime64[ns](1), float64(5), int64(1)
# memory usage: 13.9 KB

# %%
data.set_index(data['Date'])
# Out:
#                  Date        Open        High         Low       Close  \
# Date
# 2022-01-03 2022-01-03  382.583344  400.356659  378.679993  399.926666
# 2022-01-04 2022-01-04  396.516663  402.666656  374.350006  383.196655
# 2022-01-05 2022-01-05  382.216675  390.113342  360.336670  362.706665
# 2022-01-06 2022-01-06  359.000000  362.666656  340.166656  354.899994
# 2022-01-07 2022-01-07  360.123322  360.309998  336.666656  342.320007
# ...               ...         ...         ...         ...         ...
# 2022-12-23 2022-12-23  126.370003  128.619995  121.019997  123.150002
# 2022-12-27 2022-12-27  117.500000  119.669998  108.760002  109.099998
# 2022-12-28 2022-12-28  110.349998  116.269997  108.239998  112.709999
# 2022-12-29 2022-12-29  120.389999  123.570000  117.500000  121.820000
# 2022-12-30 2022-12-30  119.949997  124.480003  119.750000  123.180000
#
#              Adj Close     Volume
# Date
# 2022-01-03  399.926666  103931400
# 2022-01-04  383.196655  100248300
# ...

# %%
data=data.set_index('Date',drop=True)

# %%
data.head()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2022-01-03  382.583344  400.356659  378.679993  399.926666  399.926666
# 2022-01-04  396.516663  402.666656  374.350006  383.196655  383.196655
# 2022-01-05  382.216675  390.113342  360.336670  362.706665  362.706665
# 2022-01-06  359.000000  362.666656  340.166656  354.899994  354.899994
# 2022-01-07  360.123322  360.309998  336.666656  342.320007  342.320007
#
#                Volume
# Date
# 2022-01-03  103931400
# 2022-01-04  100248300
# 2022-01-05   80119800
# 2022-01-06   90336600
# 2022-01-07   84164700

# %%
#datatime
from datetime import datetime

# %%
datetime(2022,11,1)
# Out:
# datetime.datetime(2022, 11, 1, 0, 0)

# %%
datetime.now()
# Out:
# datetime.datetime(2023, 12, 16, 11, 41, 28, 442638)

# %%
#to calculate the operation time for a program execution
def add_num(num1,num2):
  return num1+num2

# %%
start_time = datetime.now()
num1=200
num2=300

add_num(num1,num2)
end_time = datetime.now()
print(end_time-start_time)
# Out:
# 0:00:00.000269

# %%
 datetime
# Out:
# datetime.datetime

# %%
#Time Resampling

# %%
data.resample(rule='A').min()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2022-12-31  110.349998  116.269997  108.239998  109.099998  109.099998
#
#               Volume
# Date
# 2022-12-31  41864700

# %%
data.resample(rule='A').max()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2022-12-31  396.516663  402.666656  378.679993  399.926666  399.926666
#
#                Volume
# Date
# 2022-12-31  221923300

# %%
data.resample(rule='B').max()['Low'].plot()
# Out:
# <Axes: xlabel='Date'>

# %%
data.resample(rule='QS ').max()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2022-01-01  396.516663  402.666656  378.679993  399.926666  399.926666
# 2022-04-01  378.766663  384.290009  362.433319  381.816681  381.816681
# 2022-07-01  311.666656  314.666656  305.579987  309.320007  309.320007
# 2022-10-01  254.500000  257.500000  242.009995  249.440002  249.440002
#
#                Volume
# Date
# 2022-01-01  151565700
# 2022-04-01  144973200
# 2022-07-01  142032300
# 2022-10-01  221923300

# %%
data.resample(rule='QS ').max()['High'].plot()
# Out:
# <Axes: xlabel='Date'>

# %%
data.resample(rule='MS ').max()['High'].plot()
# Out:
# <Axes: xlabel='Date'>

# %%
data.resample(rule='QS').mean().plot(kind='bar')
# Out:
# <Axes: xlabel='Date'>

# %%
#rolling means after
data['High'].rolling(11).mean()
# Out:
# Date
# 2022-01-03           NaN
# 2022-01-04           NaN
# 2022-01-05           NaN
# 2022-01-06           NaN
# 2022-01-07           NaN
#                  ...
# 2022-12-23    157.153635
# 2022-12-27    151.441817
# 2022-12-28    145.887272
# 2022-12-29    141.207271
# 2022-12-30    137.830908
# Name: High, Length: 251, dtype: float64

# %%
data['High'].rolling(11).mean().head(20)
# Out:
# Date
# 2022-01-03           NaN
# 2022-01-04           NaN
# 2022-01-05           NaN
# 2022-01-06           NaN
# 2022-01-07           NaN
# 2022-01-10           NaN
# 2022-01-11           NaN
# 2022-01-12           NaN
# 2022-01-13           NaN
# 2022-01-14           NaN
# 2022-01-18    370.803633
# 2022-01-19    366.367271
# 2022-01-20    361.326666
# 2022-01-21    356.302726
# 2022-01-24    351.621213
# 2022-01-25    347.691820
# 2022-01-26    345.527882
# 2022-01-27    341.271518
# 2022-01-28    333.473336
# 2022-01-31    328.091214
# Name: High, dtype: float64

# %%
data[['Open','Close']].plot()
# Out:
# <Axes: xlabel='Date'>
